# %% [markdown]
# # chapter no 6

# %% [markdown]
# # Data loading, Storage, anf file format

# %% [markdown]
# # 6.1 Reading and writing Data in text format

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('examples/ex1.csv',sep= ',')

# %%
df
# Out:
#   a\tb\tc\td\tmeassage
# 0    1\t2\t3\t4\thello
# 1    5\t6\t7\t8\tworld
# 2   9\t10\t11\t12\tfoo

# %%
df = pd.read_csv('allTask.csv')

# %%
df
# Out:
#       Unnamed: 0 Unnamed: 1          Unnamed: 2 Unnamed: 3  \
# 0          State    ZipCode       TaxRegionName  StateRate
# 1             AL      35004               MOODY   0.040000
# 2             AL      35005          ADAMSVILLE   0.040000
# 3             AL      35006    JEFFERSON COUNTY   0.040000
# 4             AL      35007           ALABASTER   0.040000
# 5             AL      35010           ALEXANDER   0.040000
# 6             AL      35011           ALEXANDER   0.040000
# 7             AL      35013             ALLGOOD   0.040000
# 8             AL      35014    TALLADEGA COUNTY   0.040000
# 9             AL      35015            IRONDALE   0.040000
# 10            AL      35016  ARAB (MARSHALL CO)   0.040000
# 11            AL      35019      CULLMAN COUNTY   0.040000
# 12            AL      35020            BESSEMER   0.040000
# 13            AL      35021            BESSEMER   0.040000
# 14            AL      35022            BESSEMER   0.040000
# ...

# %%
df1 =pd.read_csv('allData.csv',header = None)

# %%
df1
# Out:
#          0                      1              2      3                     4
# 0      NaN  EstimatedCombinedRate  from_postcode  state  to_postcode_ taxrate
# 1      0.0                    0.0          99501     AK                 99927
# 2      1.0                    0.0          19701     DE                 19980
# 3      2.0                   0.03          99547     AK                 99840
# 4      3.0                   0.04          99554     AK                 99832
# 5      4.0                   0.04          80116     CO                 80135
# 6      5.0                   0.04          96708     HI                 96793
# 7      6.0                   0.05          99555     AK                 99921
# 8      7.0                   0.05          35032     AL                 36866
# 9      8.0                   0.05          80126     CO                 80163
# 10     9.0                   0.02          99557     AK                 99841
# ...

# %%
df1
# Out:
#          0                      1              2      3                     4
# 0      NaN  EstimatedCombinedRate  from_postcode  state  to_postcode_ taxrate
# 1      0.0                    0.0          99501     AK                 99927
# 2      1.0                    0.0          19701     DE                 19980
# 3      2.0                   0.03          99547     AK                 99840
# 4      3.0                   0.04          99554     AK                 99832
# 5      4.0                   0.04          80116     CO                 80135
# 6      5.0                   0.04          96708     HI                 96793
# 7      6.0                   0.05          99555     AK                 99921
# 8      7.0                   0.05          35032     AL                 36866
# 9      8.0                   0.05          80126     CO                 80163
# 10     9.0                   0.02          99557     AK                 99841
# ...

# %%
# !cat examples/ex1.csv

a,b,c,d,message
1,2,3,4,hello
5,6,7,8,world
9,10,11,12,foo
# Out:
# a	b	c	d	meassage
# 1	2	3	4	hello
# 5	6	7	8	world
# 9	10	11	12	foo
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-413b145ff7da> in <module>
#       1 get_ipython().system('cat examples/ex1.csv')
#       2
# ----> 3 a,b,c,d,message
#       4 1,2,3,4,hello
#       5 5,6,7,8,world
#
# NameError: name 'a' is not defined

# %%
df = pd.read_csv('examples/ex1.csv',sep = '\s+')

# %%
df
# Out:
#    a   b   c   d meassage
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12      foo

# %%
df1= pd.read_table('examples/ex1.csv')
# Out:
# C:\Users\aac\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#    a   b   c   d meassage
# 0  1   2   3   4    hello
# 1  5   6   7   8    world
# 2  9  10  11  12      foo

# %%
# !cat examples/ex2.csv

1,2,3,4,'hello'
5,6,7,8,'world'
9,10,11,12,'foo'
# Out:
# (9, 10, 11, 12, 'foo')

# %%
 pd.read_csv('examples/ex1.csv',  sep='\s+' , header = None )
# Out:
#    0   1   2   3         4
# 0  a   b   c   d  meassage
# 1  1   2   3   4     hello
# 2  5   6   7   8     world
# 3  9  10  11  12       foo

# %%
pd.read_csv('examples/ex1.csv', names= ['a','b','c','d','message'])
# Out:
# C:\Users\aac\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                       a   b   c   d  message
# 0  a\tb\tc\td\tmeassage NaN NaN NaN      NaN
# 1     1\t2\t3\t4\thello NaN NaN NaN      NaN
# 2     5\t6\t7\t8\tworld NaN NaN NaN      NaN
# 3    9\t10\t11\t12\tfoo NaN NaN NaN      NaN

# %%
# !cat examples/ex2.csv
1,2,3,4,hello
5,6,7,8,world
9,10,11,12,foo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-99c434143b18> in <module>
#       1 get_ipython().system('cat examples/ex2.csv')
# ----> 2 1,2,3,4,hello
#       3 5,6,7,8,world
#       4 9,10,11,12,foo
#
# NameError: name 'hello' is not defined

# %%
pd.read_csv('examples/ex1.csv', sep='\s+',index_col= 'meassage')
# Out:
#           a   b   c   d
# meassage
# hello     1   2   3   4
# world     5   6   7   8
# foo       9  10  11  12

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-71cdb4226f6f> in <module>
#       1 get_ipython().system('cat examples/csv_mindex.csv')
# ----> 2 key1,key2,value1,value2
#       3 one,a,1,2
#       4 one,b,3,4
#       5 one,c,5,6
#
# NameError: name 'key1' is not defined

# %%
pd.options.display.max_rows = 10

# %%
pd.read_csv('allTask.csv')
# Out:
#       Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3  \
# 0          State    ZipCode     TaxRegionName  StateRate
# 1             AL      35004             MOODY   0.040000
# 2             AL      35005        ADAMSVILLE   0.040000
# 3             AL      35006  JEFFERSON COUNTY   0.040000
# 4             AL      35007         ALABASTER   0.040000
# ...          ...        ...               ...        ...
# 12507         IN      47993     WILLIAMSPORT    0.070000
# 12508         IN      47994        MONTGOMERY   0.070000
# 12509         IN      47995             WHITE   0.070000
# 12510         IN      47996   WEST LAFAYETTE    0.070000
# 12511         IN      47997           YEOMAN    0.070000
#
#                   Unnamed: 4           Unnamed: 5         Unnamed: 6  \
# 0      EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate
# 1                   0.100000                    0           0.040000
# 2                   0.100000             0.010000           0.040000
# ...

# %%
pd.read_csv('allTask.csv', nrows = 5 )
# Out:
#   Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3             Unnamed: 4  \
# 0      State    ZipCode     TaxRegionName  StateRate  EstimatedCombinedRate
# 1         AL      35004             MOODY   0.040000               0.100000
# 2         AL      35005        ADAMSVILLE   0.040000               0.100000
# 3         AL      35006  JEFFERSON COUNTY   0.040000               0.060000
# 4         AL      35007         ALABASTER   0.040000               0.090000
#
#             Unnamed: 5         Unnamed: 6            Unnamed: 7      State
# 0  EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  RiskLevel
# 1                    0           0.040000              0.020000          2
# 2             0.010000           0.040000              0.010000          1
# 3             0.010000                  0              0.010000          2
# 4             0.010000           0.040000                     0          1

# %% [markdown]
# # Writing Data to Text Format

# %%
df1.to_csv('examples/ex1.csv')

# %%
# !cat examples/ex1.csv
something,a,b,c,d,message
0,one,1,2,3.0,4,
1,two,5,6,7,8,world
2,three,9,10,11.0,12,foo
# Out:
# ,0
# 0,a	b	c	d	meassage
# 1,1	2	3	4	hello
# 2,5	6	7	8	world
# 3,9	10	11	12	foo
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-654400f9ea55> in <module>
#       1 get_ipython().system('cat examples/ex1.csv')
# ----> 2 something,a,b,c,d,message
#       3 0,one,1,2,3.0,4,
#       4 1,two,5,6,7,8,world
#       5 2,three,9,10,11.0,12,foo
#
# NameError: name 'something' is not defined

# %%
import sys

# %%
data.to_csv(sys.stdout, sep='|')
something|a|b|c|d|message
0|one|1|2|3.0|4
1|two|5|6|7|8|world
2|three|9|10|11.0|12|foo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-8589b9ec25e3> in <module>
# ----> 1 data.to_csv(sys.stdout, sep='|')
#       2 something|a|b|c|d|message
#       3 0|one|1|2|3.0|4
#       4 1|two|5|6|7|8|world
#       5 2|three|9|10|11.0|12|foo
#
# NameError: name 'data' is not defined

# %%
# !cat examples/ex7.csv
"a","b","c"
"1","2","3"
"1","2","3"
# Out:
# ('1', '2', '3')

# %%
import csv

# %%
f = open('examples/ex7.csv')

# %%
reader =csv.reader(f)

# %%
for line in reader:
    print(line)
    ['a', 'b', 'c']
    ['1', '2', '3']
    ['1', '2', '3']

# %% [markdown]
# # Json Data Format

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
 {"name": "Katie", "age": 38,
 "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json

# %%
result =json.loads(obj)

# %%
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])

# %%
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
# !cat examples/example.json
[{"a": 1, "b": 2, "c": 3},
{"a": 4, "b": 5, "c": 6},
{"a": 7, "b": 8, "c": 9}]
# Out:
# [{'a': 1, 'b': 2, 'c': 3}, {'a': 4, 'b': 5, 'c': 6}, {'a': 7, 'b': 8, 'c': 9}]

# %%
data = pd.read_json('examples/example.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-7a2c57175d12> in <module>
# ----> 1 data = pd.read_json('examples/example.json')
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     425         return json_reader
#     426
# --> 427     result = json_reader.read()
#     428     if should_close:
#     429         try:
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     535             )
#     536         else:
# --> 537             obj = self._get_object_parser(self.data)
#     538         self.close()
#     539         return obj
#
# ~\Anaconda3\lib\site-packages\pandas\io\json\json.py in _get_object_parser(self, json)
#     554         obj = None
# ...
